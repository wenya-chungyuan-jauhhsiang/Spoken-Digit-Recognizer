# %% [markdown]
# # <font color=1978DD> split_audio.py </font>

# %% [markdown]
# ## <font color=FC8600>  <font face="微软雅黑">目標</font>

# %% [markdown]
# #### <font color=0E0E0E>  <font face="微软雅黑">split_audio目標將使用者輸入的音檔切割，輸出只包含一個數字的音檔。</font>

# %% [markdown]
# ## <font color=FC8600>  <font face="微软雅黑">使用套件</font>

# %% [markdown]
# #### <font color=0E0E0E>  <font face="微软雅黑">利用pydub套件引入AudioSegment以及split_on_silence函式庫，藉由這些函式以及調整參數，確保切割出的音檔具有穩定品質。 </font>

# %% [markdown]
# ## <font color=FC8600>  <font face="微软雅黑">待調參數</font>

# %% [markdown]
# #### <font color=0E0E0E>  <font face="微软雅黑">包含minimum silence length(最短靜音長度)、silence threshold(程式用以判斷是否為靜音的音量閥值)、keep silence(輸出音檔的前後所預留的靜音時間) </font>

# %% [markdown]
# ## <font color=FC8600>  <font face="微软雅黑">輸入</font>

# %% [markdown]
# #### <font color=0E0E0E>  <font face="微软雅黑">使用者會說出一串數字作為輸入，利用麥克風轉為包含多數字的單一音檔(.wav)，範例音檔如下: </font>

# %%
import IPython.display as ipd
ipd.Audio('resources/3486790251.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## <font color=FC8600>  <font face="微软雅黑">輸出</font>

# %% [markdown]
# #### <font color=0E0E0E>  <font face="微软雅黑">將包含多數字的音檔(.wav)，經過切割後，輸出多個.wav檔案，使每個輸出音檔只包含單一數字。範例音檔如下: </font>

# %%
import IPython.display as ipd
for i in range(10):
    ipd.display(ipd.Audio(f'resources/split_audio_{i}.wav'))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
# ...
